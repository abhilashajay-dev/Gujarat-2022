# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import torch.nn as nn
import torch.functional as F
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import cufflinks as cf
cf.go_offline()
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('GujAE.csv')
df1 = pd.read_csv('gujarat_AC.csv')

# %%
df1.columns
# Out:
# Index(['ac_name', 'ac_no', 'dist_name', 'dt_code', 'pc_id', 'pc_name', 'pc_no',
#        'st_code', 'st_name'],
#       dtype='object')

# %%
df1
# Out:
#             ac_name  ac_no   dist_name  dt_code  pc_id      pc_name  pc_no  \
# 0               NaN      0     KACHCHH        1   2400          NaN      0
# 1          Vejalpur     42   AHMADABAD        7   2406  GANDHINAGAR      6
# 2    Jamnagar South     79    JAMNAGAR       10   2412     JAMNAGAR     12
# 3         Manjalpur    145    VADODARA       19   2420     VADODARA     20
# 4    Bhavnagar West    105   BHAVNAGAR       14   2415    BHAVNAGAR     15
# ..              ...    ...         ...      ...    ...          ...    ...
# 183    Gandevi (ST)    176  NAVSARI  *       24   2425      NAVSARI     25
# 184       Dharampur    178      VALSAD       25   2426  VALSAD (ST)     26
# 185           Pardi    180      VALSAD       25   2426  VALSAD (ST)     26
# 186    Kaprada (ST)    181      VALSAD       25   2426  VALSAD (ST)     26
# 187       Umbergaon    182  NAVSARI  *       24   2426  VALSAD (ST)     26
#
#      st_code  st_name
# 0         24  GUJARAT
# 1         24  GUJARAT
# 2         24  GUJARAT
# 3         24  GUJARAT
# 4         24  GUJARAT
# ..       ...      ...
# 183       24  GUJARAT
# 184       24  GUJARAT
# 185       24  GUJARAT
# 186       24  GUJARAT
# 187       24  GUJARAT
#
# [188 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Election_Type', 'State_Name', 'Assembly_No', 'Constituency_No', 'Year',
#        'month', 'Poll_No', 'DelimID', 'Position', 'Candidate', 'Sex', 'Party',
#        'Votes', 'Candidate_Type', 'Valid_Votes', 'Electors',
#        'Constituency_Name', 'Constituency_Type', 'Sub_Region', 'N_Cand',
#        'Turnout_Percentage', 'Vote_Share_Percentage', 'Deposit_Lost', 'Margin',
#        'Margin_Percentage', 'ENOP', 'pid', 'Party_Type_TCPD', 'Party_ID',
#        'last_poll', 'Contested', 'Last_Party', 'Last_Party_ID',
#        'Last_Constituency_Name', 'Same_Constituency', 'Same_Party', 'No_Terms',
#        'Turncoat', 'Incumbent', 'Recontest', 'Age', 'District_Name', 'PC_Name',
#        'PC_No', 'CandID', 'MyNeta_education', 'TCPD_Prof_Main',
#        'TCPD_Prof_Main_Desc', 'TCPD_Prof_Second', 'TCPD_Prof_Second_Desc'],
#       dtype='object')

# %%
df.rename(columns={'Constituency_No':'ac_no'}, inplace=True)

# %%
final_df = pd.merge(df, df1, on="ac_no", how='inner')

# %%
final_df
# Out:
#      Election_Type State_Name  Assembly_No  ac_no  Year  month  Poll_No  \
# 0               AE    Gujarat           11      1  2007     12        0
# 1               AE    Gujarat           11      1  2007     12        0
# 2               AE    Gujarat           11      1  2007     12        0
# 3               AE    Gujarat           11      1  2007     12        0
# 4               AE    Gujarat           11      1  2007     12        0
# ...            ...        ...          ...    ...   ...    ...      ...
# 5247            AE    Gujarat           13    182  2017     12        0
# 5248            AE    Gujarat           13    182  2017     12        0
# 5249            AE    Gujarat           13    182  2017     12        0
# 5250            AE    Gujarat           13    182  2017     12        0
# 5251            AE    Gujarat           13    182  2017     12        0
#
#       DelimID  Position                         Candidate  ...  \
# 0           3         1   JAYANTILAL PARSOTTAM BHANUSHALI  ...
# 1           3         2  JADEJA NARENDRASINH MADHAVSINHJI  ...
# 2           3         3           HALEPOTRA IBRAHIM JAFAR  ...
# 3           3         4    BHAVANI HANSRAJBHAI PARBATBHAI  ...
# 4           3         5   KULINKANT BHOJRAJ SHAH (LODAYA)  ...
# ...       ...       ...                               ...  ...
# 5247        4         4      BOCHAL HASMUKHBHAI RAMANBHAI  ...
# 5248        4         5    SHAILESHBHAI UKADBHAI DABHADIA  ...
# 5249        4         6      NARESHBHAI UKKADBHAI OZARIYA  ...
# 5250        4         7     VADIYA LAXMANBHAI CHHAGANBHAI  ...
# 5251        4         8        GOVINDBHAI VESTABHAI PATEL  ...
#
#      TCPD_Prof_Second TCPD_Prof_Second_Desc    ac_name   dist_name  dt_code  \
# 0                 NaN                   NaN     Abdasa     KACHCHH        1
# 1                 NaN                   NaN     Abdasa     KACHCHH        1
# 2                 NaN                   NaN     Abdasa     KACHCHH        1
# 3                 NaN                   NaN     Abdasa     KACHCHH        1
# 4                 NaN                   NaN     Abdasa     KACHCHH        1
# ...               ...                   ...        ...         ...      ...
# 5247      Agriculture                   NaN  Umbergaon  NAVSARI  *       24
# 5248              NaN                   NaN  Umbergaon  NAVSARI  *       24
# 5249              NaN                   NaN  Umbergaon  NAVSARI  *       24
# 5250              NaN                   NaN  Umbergaon  NAVSARI  *       24
# 5251              NaN                   NaN  Umbergaon  NAVSARI  *       24
#
#       pc_id       pc_name pc_no st_code  st_name
# 0      2401  KACHCHH (SC)     1      24  GUJARAT
# 1      2401  KACHCHH (SC)     1      24  GUJARAT
# 2      2401  KACHCHH (SC)     1      24  GUJARAT
# 3      2401  KACHCHH (SC)     1      24  GUJARAT
# 4      2401  KACHCHH (SC)     1      24  GUJARAT
# ...     ...           ...   ...     ...      ...
# 5247   2426   VALSAD (ST)    26      24  GUJARAT
# 5248   2426   VALSAD (ST)    26      24  GUJARAT
# 5249   2426   VALSAD (ST)    26      24  GUJARAT
# 5250   2426   VALSAD (ST)    26      24  GUJARAT
# 5251   2426   VALSAD (ST)    26      24  GUJARAT
#
# [5252 rows x 58 columns]

# %%
def win(x):
    if x == 1:
        return True
    else:
        return False

# %%
final_df['winner'] = final_df['Position'].apply(win)

# %%
final_df.head()
# Out:
#   Election_Type State_Name  Assembly_No  ac_no  Year  month  Poll_No  DelimID  \
# 0            AE    Gujarat           11      1  2007     12        0        3
# 1            AE    Gujarat           11      1  2007     12        0        3
# 2            AE    Gujarat           11      1  2007     12        0        3
# 3            AE    Gujarat           11      1  2007     12        0        3
# 4            AE    Gujarat           11      1  2007     12        0        3
#
#    Position                         Candidate  ... TCPD_Prof_Second_Desc  \
# 0         1   JAYANTILAL PARSOTTAM BHANUSHALI  ...                   NaN
# 1         2  JADEJA NARENDRASINH MADHAVSINHJI  ...                   NaN
# 2         3           HALEPOTRA IBRAHIM JAFAR  ...                   NaN
# 3         4    BHAVANI HANSRAJBHAI PARBATBHAI  ...                   NaN
# 4         5   KULINKANT BHOJRAJ SHAH (LODAYA)  ...                   NaN
#
#   ac_name  dist_name dt_code  pc_id       pc_name pc_no st_code  st_name  \
# 0  Abdasa    KACHCHH       1   2401  KACHCHH (SC)     1      24  GUJARAT
# 1  Abdasa    KACHCHH       1   2401  KACHCHH (SC)     1      24  GUJARAT
# 2  Abdasa    KACHCHH       1   2401  KACHCHH (SC)     1      24  GUJARAT
# 3  Abdasa    KACHCHH       1   2401  KACHCHH (SC)     1      24  GUJARAT
# 4  Abdasa    KACHCHH       1   2401  KACHCHH (SC)     1      24  GUJARAT
#
#    winner
# 0    True
# 1   False
# 2   False
# 3   False
# 4   False
#
# [5 rows x 59 columns]

# %%
final_df.to_csv('Final_df.csv')

# %%
len(final_df)
# Out:
# 5252

# %% [markdown]
# # Separating final_df based on years Assembly Elections were held

# %%
final_df['Year'].unique()
# Out:
# array([2007, 2012, 2014, 2017, 2009, 2010, 2013, 2011, 2016], dtype=int64)

# %%
final_df_2017 = final_df[final_df['Year'] == 2017]
final_df_2012 = final_df[final_df['Year'] == 2012]
final_df_2007 = final_df[final_df['Year'] == 2007]

# %%
final_df_2007['ac_no'].nunique(), final_df_2012['ac_no'].nunique(), final_df_2017['ac_no'].nunique()
# Out:
# (182, 182, 182)

# %%
final_df_2007[final_df_2007['winner']]['Party'].value_counts()
# Out:
# BJP      116
# INC       59
# NCP        3
# IND        2
# BJNKP      1
# JD(U)      1
# Name: Party, dtype: int64

# %%
final_df_2012[final_df_2012['winner']]['Party'].value_counts()
# Out:
# BJP      115
# INC       62
# NCP        2
# GPP        2
# IND        1
# JD(U)      1
# Name: Party, dtype: int64

# %%
final_df_2017[final_df_2017['winner']]['Party'].value_counts()
# Out:
# BJP    99
# INC    77
# IND     3
# BTP     2
# NCP     1
# Name: Party, dtype: int64

# %%
import geopandas as gd

# %%
sh = gd.read_file('gujarat_AC/gujarat_AC.shp')

# %%
sh
# Out:
#             ac_name ac_no   dist_name dt_code pc_id      pc_name pc_no  \
# 0              None     0     KACHCHH      01  2400         None     0
# 1          Vejalpur    42   AHMADABAD      07  2406  GANDHINAGAR     6
# 2    Jamnagar South    79    JAMNAGAR      10  2412     JAMNAGAR    12
# 3         Manjalpur   145    VADODARA      19  2420     VADODARA    20
# 4    Bhavnagar West   105   BHAVNAGAR      14  2415    BHAVNAGAR    15
# ..              ...   ...         ...     ...   ...          ...   ...
# 183    Gandevi (ST)   176  NAVSARI  *      24  2425      NAVSARI    25
# 184       Dharampur   178      VALSAD      25  2426  VALSAD (ST)    26
# 185           Pardi   180      VALSAD      25  2426  VALSAD (ST)    26
# 186    Kaprada (ST)   181      VALSAD      25  2426  VALSAD (ST)    26
# 187       Umbergaon   182  NAVSARI  *      24  2426  VALSAD (ST)    26
#
#     st_code  st_name                                           geometry
# 0        24  GUJARAT  POLYGON ((71.28745 24.61599, 71.28326 24.60684...
# 1        24  GUJARAT  POLYGON ((72.52746 23.04147, 72.52856 23.02979...
# 2        24  GUJARAT  POLYGON ((70.11326 22.46063, 70.12055 22.44272...
# 3        24  GUJARAT  POLYGON ((73.23656 22.29109, 73.26373 22.28369...
# 4        24  GUJARAT  POLYGON ((72.08070 21.81342, 72.07363 21.79259...
# ..      ...      ...                                                ...
# 183      24  GUJARAT  POLYGON ((73.12570 20.89856, 73.13476 20.89720...
# 184      24  GUJARAT  POLYGON ((73.01926 20.71072, 73.03361 20.70157...
# 185      24  GUJARAT  POLYGON ((72.98923 20.51996, 72.99961 20.51646...
# 186      24  GUJARAT  POLYGON ((73.07248 20.47422, 73.07690 20.47072...
# 187      24  GUJARAT  POLYGON ((72.98017 20.28852, 72.98083 20.27431...
#
# [188 rows x 10 columns]

# %%
sh.to_file("sh.geojson", driver='GeoJSON')

# %%
import json

# %%
gujarat_con = json.load(open("sh.geojson", "r"))

# %%
gujarat_con['features'][0].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry'])

# %%
import plotly.express as px

# %%
import plotly.io as pio

# %%
pio.renderers.default = 'firefox'

# %%
final_df_2017_winner = final_df_2017[final_df_2017['winner'] == True]

# %%
len(final_df_2017_winner)
# Out:
# 182

# %%
fig =px.choropleth(final_df_2017_winner, locations='ac_no', geojson=gujarat_con, color='Party', scope='asia')
fig.update_geos(fitbounds=locations, visible=False)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       1 fig =px.choropleth(final_df_2017_winner, locations='ac_no', geojson=gujarat_con, color='Party', scope='asia')
# ----> 2 fig.update_geos(fitbounds=locations, visible=False)
#       3 fig.show()
#
# NameError: name 'locations' is not defined

# %%
state_id_map = {}
for feature in gujarat_con['features']:
    feature['id'] = feature['properties']['ac_no']
    state_id_map[feature['properties']['ac_name']] = feature['id']

# %%
gujarat_con['features'][0]['properties']
# Out:
# {'ac_name': None,
#  'ac_no': '0',
#  'dist_name': 'KACHCHH',
#  'dt_code': '01',
#  'pc_id': '2400',
#  'pc_name': None,
#  'pc_no': '0',
#  'st_code': '24',
#  'st_name': 'GUJARAT'}

# %%
state_id_map
# Out:
# {None: '0',
#  'Vejalpur': '42',
#  'Jamnagar South': '79',
#  'Manjalpur': '145',
#  'Bhavnagar West': '105',
#  'Vansda (ST)': '177',
#  'Rajkot South': '70',
#  'Kankrej': '15',
#  'Bhuj': '3',
#  'Amraiwadi': '50',
#  'Kheralu': '20',
#  'Visnagar': '22',
#  'Mansa': '37',
#  'Kadi (SC)': '24',
#  'Surat East': '159',
#  'Lunawada': '122',
#  'Gandhinagar(North)': '36',
#  'Vatva': '43',
#  'Kapadvanj': '120',
#  'Ghatlodia': '41',
#  'Jamalpur-Khadia': '52',
#  'Morva Hadaf': '125',
#  'Jhalod (ST)': '130',
#  'Tankara': '66',
#  'Savli': '135',
#  'Anand': '112',
#  'Rajkot West': '69',
#  'Surat West': '167',
#  'Sayajigunj': '142',
#  'Padra': '146',
#  'Jambusar': '150',
#  'Porbandar': '83',
#  'Bharuch': '153',
#  'Karanj': '162',
#  'Ankleshwar': '154',
#  'Somnath': '90',
#  'Naroda': '47',
#  'Bardoli (SC)': '169',
#  'Tharad': '8',
#  'Deesa': '13',
#  'Varachha Road': '161',
#  'Vav': '7',
#  'Majura': '165',
#  'Unjha': '21',
#  'Udhna': '164',
#  'Limbayat': '163',
#  'Dhanera': '9',
#  'Surat North': '160',
#  'Danta (ST)': '10',
#  'Deodar': '14',
#  'Khedbrahma(ST)': '29',
#  'Katargam': '166',
#  'Palanpur': '12',
#  'Vijapur': '26',
#  'Vadgam (SC)': '11',
#  'Sidhpur': '19',
#  'Ellisbridge': '44',
#  'Radhanpur': '16',
#  'Abdasa': '1',
#  'Naranpura': '45',
#  'Patan': '18',
#  'Sabarmati': '55',
#  'Chanasma': '17',
#  'Bhiloda (ST)': '30',
#  'Rapar': '6',
#  'Idar (SC)': '28',
#  'Mahesana': '25',
#  'Becharaji': '23',
#  'Himatnagar': '27',
#  'Modasa': '31',
#  'Gandhidham(SC)': '5',
#  'Anjar': '4',
#  'Prantij': '33',
#  'Gandhinagar(South)': '35',
#  'Dasada (SC)': '60',
#  'Viramgam': '39',
#  'Asarwa': '56',
#  'Bayad': '32',
#  'Dahegam': '34',
#  'Dariyapur': '51',
#  'Mandvi': '2',
#  'Santrampur': '123',
#  'Dhrangadhra': '64',
#  'Morbi': '65',
#  'Fatepura (ST)': '129',
#  'Danilimda': '54',
#  'Thakkar Bapanagar': '48',
#  'Kalol': '127',
#  'Nikol': '46',
#  'Balasinor': '121',
#  'Bapunagar': '49',
#  'Sanand': '40',
#  'Wadhwan': '62',
#  'Maninagar': '53',
#  'Daskroi': '57',
#  'Kalavad (SC)': '76',
#  'Wankaner': '67',
#  'Jamnagar': '77',
#  'Shehra': '124',
#  'Limkheda (ST)': '131',
#  'Chotila': '63',
#  'Mehmedabad': '117',
#  'Thasra': '119',
#  'Dholka': '58',
#  'Dahod (ST)': '132',
#  'Mahudha': '118',
#  'Godhra': '126',
#  'Matar': '115',
#  'Devgadhbaria': '134',
#  'Limbdi': '61',
#  'Dwarka': '82',
#  'Garbada (ST)': '133',
#  'Umreth': '111',
#  'Nadiad': '116',
#  'Jamnagar North': '78',
#  'Khambhalia': '81',
#  'Sojitra': '114',
#  'Jamjodhpur': '80',
#  'Petlad': '113',
#  'Chhota Udaipur (ST': '137',
#  'Dhandhuka': '59',
#  'Anklav': '110',
#  'Halol': '128',
#  'Khambhat': '108',
#  'Rajkot Rural(SC)': '71',
#  'Vaghodia': '136',
#  'Borsad': '109',
#  'Botad': '107',
#  'Rajkot East': '68',
#  'Jasdan': '72',
#  'Mahuva (ST)': '170',
#  'Sankheda(ST)': '139',
#  'Vadodara City(SC)': '141',
#  'Raopura': '144',
#  'Akota': '143',
#  'Jetpur (ST)': '138',
#  'Choryasi': '168',
#  'Dabhoi': '140',
#  'Gondal': '73',
#  'Gadhada (SC)': '106',
#  'Jetpur': '74',
#  'Dhoraji': '75',
#  'Bhavnagar Rural': '103',
#  'Karjan': '147',
#  'Lathi': '96',
#  'Kutiyana': '84',
#  'Nandod (ST)': '148',
#  'Amreli': '95',
#  'Vagra': '151',
#  'Jhagadia (ST)': '152',
#  'Manavadar': '85',
#  'Bhavnagar East': '104',
#  'Palitana': '102',
#  'Junagadh': '86',
#  'Kodinar (SC)': '92',
#  'Visavadar': '87',
#  'Gariadhar': '101',
#  'Keshod': '88',
#  'Dhari': '94',
#  'Savarkundla': '97',
#  'Dediapada(ST)': '149',
#  'Valsad': '179',
#  'Talaja': '100',
#  'Mangrol (ST)': '156',
#  'Talala': '91',
#  'Nizar (ST)': '172',
#  'Olpad': '155',
#  'Mandvi (ST)': '157',
#  'Mangrol': '89',
#  'Kamrej': '158',
#  'Una': '93',
#  'Mahuva': '99',
#  'Rajula': '98',
#  'Vyara (ST)': '171',
#  'Jalalpore': '174',
#  'Navsari': '175',
#  'Dangs (ST)': '173',
#  'Gandevi (ST)': '176',
#  'Dharampur': '178',
#  'Pardi': '180',
#  'Kaprada (ST)': '181',
#  'Umbergaon': '182'}
